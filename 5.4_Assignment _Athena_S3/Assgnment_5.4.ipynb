# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_parquet('earnings_date=2022-02-10')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   emp_id           100 non-null    int64
#  1   first_name       100 non-null    object
#  2   middle_initial   100 non-null    object
#  3   last_name        100 non-null    object
#  4   email            100 non-null    object
#  5   date_of_birth    100 non-null    object
#  6   date_of_joining  100 non-null    object
#  7   ssn              100 non-null    object
#  8   phone_number     100 non-null    object
#  9   user_name        100 non-null    object
#  10  password         100 non-null    object
#  11  office_branch    100 non-null    object
#  12  earnings         100 non-null    int64
# dtypes: int64(2), object(11)
# memory usage: 10.3+ KB

# %%
df
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
def create_data_frames():
    min_value = df["earnings"].min()
    avg_value = df["earnings"].max()
    df['earnings'] = np.random.randint(min_value, avg_value, size=df.shape[0])
    return df

# %%
print(create_data_frames())
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
for i in range(2):
    table=create_data_frames()
    table.to_parquet("earnings_data{}".format(i))

# %%
a= pd.read_parquet('earning_employee_data0/earnings_data0')
a
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
b= pd.read_parquet('earning_employee_data1/earnings_data1')
b
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
table.to_csv("date")

# %%
a= pd.read_csv('date')
a
# Out:
#     Unnamed: 0  emp_id first_name middle_initial last_name  \
# 0            0  526540  Angelique              K   Goodwin
# 1            1  859327       Jeni              S   Shaffer
# 2            2  887387     Donald              T    Farris
# 3            3  779497     Steven              D    Rendon
# 4            4  896517     Jenell              L   Almanza
# ..         ...     ...        ...            ...       ...
# 95          95  549389   Clemente              M     Gould
# 96          96  466832      Chang              K     Roden
# 97          97  203380     Marvin              R    Nickel
# 98          98  915991     Eldora              Y   Tribble
# 99          99  289172      Azzie              L    Layman
#
#                            email date_of_birth date_of_joining          ssn  \
# 0    angelique.goodwin@gmail.com    1964-05-15      2001-03-24  471-57-0359
# 1         jeni.shaffer@gmail.com    1962-01-13      2015-12-10  624-85-4146
# ...

# %%
def generate_data(a):
    min_values = df['earnings'].min()
    average_values = df['earnings'].mean()
    for i in range(a):
        df['earnings'] = np.random.randint(min_values, average_values, size=df.shape[0])
        filename = f"dataframe{i}.parquet"  # Use string formatting to create the filename
        df.to_parquet(filename)
    return df

# %%
generate_data(2)
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   emp_id           100 non-null    int64
#  1   first_name       100 non-null    object
#  2   middle_initial   100 non-null    object
#  3   last_name        100 non-null    object
#  4   email            100 non-null    object
#  5   date_of_birth    100 non-null    object
#  6   date_of_joining  100 non-null    object
#  7   ssn              100 non-null    object
#  8   phone_number     100 non-null    object
#  9   user_name        100 non-null    object
#  10  password         100 non-null    object
#  11  office_branch    100 non-null    object
#  12  earnings         100 non-null    int64
# dtypes: int64(2), object(11)
# memory usage: 10.3+ KB
